# %% [markdown]
# <font size="6">**Introduzione a Python per Banca Popolare di Puglia e Basilicata**</font><br>
#
# > (c) 2025 Antonio Piemontese

# %%
print("Hello world")
import pandas as pd
# Out:
# Hello world
